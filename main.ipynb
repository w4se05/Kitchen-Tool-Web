# %%
import os
from pathlib import Path
from ultralytics import YOLO
current_dir = Path.cwd()
MODEL_LOCAL_PATH = os.path.join(current_dir, "models", "best_kc_tool.pt")

# Check current directory
model = YOLO(MODEL_LOCAL_PATH)
